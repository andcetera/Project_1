# %%
import pandas as pd

testfile = 'disasters.csv'
df = pd.read_csv(testfile)
df.head()
# Out:
#   Disaster Type  Disaster Subtype Disaster Group Disaster Subgroup Event Name  \
# 0    Earthquake   Ground movement        Natural       Geophysical        NaN
# 1         Storm  Tropical cyclone        Natural    Meteorological    Indhala
# 2         Flood       Flash flood        Natural      Hydrological        NaN
# 3         Flood    Riverine flood        Natural      Hydrological        NaN
# 4         Flood    Riverine flood        Natural      Hydrological        NaN
#
#                    Origin     Country  \
# 0                     NaN       Japan
# 1                     NaN  Madagascar
# 2  Storms and heavy rains   Australia
# 3             Heavy rains       Haiti
# 4             Heavy rains   Argentina
#
#                                             Location  Latitude  Longitude  \
# 0  Nanao, Wajima districts (Isikawa province), Ni...    37.336    136.588
# 1         Diana, Sava, Sofia, Analanjirofo provinces   -14.840     49.940
# ...

# %%
df.columns
# Out:
# Index(['Disaster Type', 'Disaster Subtype', 'Disaster Group',
#        'Disaster Subgroup', 'Event Name', 'Origin', 'Country', 'Location',
#        'Latitude', 'Longitude', 'start_date', 'end_date', 'Total Deaths',
#        'No Affected', 'Reconstruction Costs ('000 US$)',
#        'Total Damages ('000 US$)', 'CPI'],
#       dtype='object')

# %%
df['Disaster Type'].value_counts()
# Out:
# Flood                  2256
# Storm                  1418
# Earthquake              345
# Extreme temperature     273
# Landslide               255
# Drought                 161
# Wildfire                135
# Volcanic activity        61
# Mass movement (dry)       9
# Name: Disaster Type, dtype: int64

# %%
climate_disasters = df.loc[(df['Disaster Subgroup'] == 'Climatological') | (df['Disaster Subtype'] == 'Coastal flood'), :]
climate_disasters.head()
# Out:
#     Disaster Type Disaster Subtype Disaster Group Disaster Subgroup  \
# 47          Flood    Coastal flood        Natural      Hydrological
# 106      Wildfire      Forest fire        Natural    Climatological
# 114      Wildfire      Forest fire        Natural    Climatological
# 115      Wildfire              NaN        Natural    Climatological
# 148       Drought          Drought        Natural    Climatological
#
#     Event Name                                          Origin      Country  \
# 47         NaN                        Heavy rains and cyclones   Madagascar
# 106        NaN            High temperatures and dry conditions      Albania
# 114        NaN  High temperatures, heavy winds, dry conditions     Bulgaria
# 115        NaN                                             NaN     Bulgaria
# 148        NaN                                             NaN  Afghanistan
#
#                                               Location  Latitude  Longitude  \
# ...

# %%
disaster_types = climate_disasters.groupby('Disaster Type')
disaster_types['Disaster Subtype'].value_counts()
# MOST OF THESE DO NOT HAVE LAT/LONG SO WE'LL NEED TO LOOK THOSE UP  -  SEE BELOW
# Out:
# Disaster Type  Disaster Subtype
# Drought        Drought                             160
# Flood          Coastal flood                        18
# Wildfire       Forest fire                          79
#                Land fire (Brush, Bush, Pasture)     31
# Name: Disaster Subtype, dtype: int64

# %%
can_map = climate_disasters.dropna(subset=['Latitude'])
print(len(can_map))
can_map
# Out:
# 7
#      Disaster Type Disaster Subtype Disaster Group Disaster Subgroup  \
# 47           Flood    Coastal flood        Natural      Hydrological
# 261          Flood    Coastal flood        Natural      Hydrological
# 343          Flood    Coastal flood        Natural      Hydrological
# 374          Flood    Coastal flood        Natural      Hydrological
# 754          Flood    Coastal flood        Natural      Hydrological
# 2544         Flood    Coastal flood        Natural      Hydrological
# 2933         Flood    Coastal flood        Natural      Hydrological
#
#      Event Name                                Origin                 Country  \
# 47          NaN              Heavy rains and cyclones              Madagascar
# 261         NaN                  Tropical storm Lando       Philippines (the)
# 343         NaN  Tropical depression in Bay of Bengal                   India
# 374         NaN           Heavy rain, Hurricane Felix                  Mexico
# ...
